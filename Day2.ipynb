# %%
                                                                                                                                                                                                                                                                                                                                                                                                                #1.swap number without using tem variable

# %%
#1
a=3
b=83
a,b=b,a
print(a)
print(b)
# Out:
# 83
# 3

# %%
a

# %%
#2
a=8
b=5
a=a+b
b=a-b
a=a-b
print(a)
print(b)
# Out:
# 5
# 8

# %%
#3
a=5
b=7
a=a*b
b=a//b
a=a//b
print(a)
print(b)
# Out:
# 7
# 5

# %%
#4
a=9
b=5
a=a^b
b=a^b
a=a^b
print(a)
print(b)
# Out:
# 5
# 9

# %%
# 2 bubble sort
a=[3,5,1,7]
n=len(a)
for i in range(n-1):
    for j in range(n-i-1):
        if(a[j]>a[j+1]):
            a[j],a[j+1]=a[j+1],a[j]
print("sorted array: ",a)
# Out:
# sorted array:  [1, 3, 5, 7]

# %%
# 3 reverse string

# %%
#1 palindrome
a="madam"
if(a==a[::-1]):
    print("pallindrome")
else:
    print("not palindrome")
# Out:
# not palindrome

# %%
# 2
a="madamfg"
a="".join(reversed(a))
print(a)
# Out:
# gfmadam

# %%
# 3
a="madam76"
rev=" "
for ch in a:
    rev=ch+rev
print(rev)
# Out:
# 67madam

# %%
#4 recurrsion
def palindrome(n):
    if(len(n)<=1):
        return True
    if(n[0]!=n[-1]):
        return False
    return palindrome(a[1:-1])
n="123821n"
print("pallinfrome" if palindrome(n) else"not pallindrome")
# Out:
# not pallindrome

# %%
# Factorail number

# %%
# 1. using the for loop
n=int(input("enter the number: "))
fact=1
for i in range(1,n+1):
    fact=fact*i
print(fact)
# Out:
# enter the number:  5
# 120

# %%
# 2 using recursion
n=int(input("enter the number: "))
fact=1
def fact(n):
    if(n==0 or n==1):
        return True
    return n*fact(n-1)
print(fact(n))
# Out:
# enter the number:  5
# 120

# %%
#3 finding factorail using while loop
n=5
fact=1
while(n>0):
    fact=fact*n
    n=n-1
print(fact)
# Out:
# 120

# %%
# 4import function
import math
print(math.factorial(5))
# Out:
# 120

# %%
# reverse the string

# %%
a="123456789"
print(a[::-1])
# Out:
# 987654321

# %%
a="123456789"
a="".join(reversed(a))
print(a)
# Out:
# 987654321

# %%
a="hello"
rev=" "
for ch in a:
    rev=ch+rev
print(rev)
# Out:
# olleh

# %%
def rev(n):
    if(len(n)<=1 or n==0):
        return True
    if(n[0]!=n[-1]):
        return False
    return rev(n[1:-1])
n="12321"
print(rev(n))
# Out:
# True

# %%
nums = [10, 5, 20, 3, 15]

min_val = nums[0]
max_val = nums[0]

for n in nums:
    if n < min_val:
        min_val = n
    if n > max_val:
        max_val = n

print("Min:", min_val)
print("Max:", max_val)
# Out:
# Min: 3
# Max: 20

# %%
nums=[4,8,5,3]
print(max(nums))
print(min(nums))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 nums=[4,8,5,3]
# ----> 2 print(max(nums))
#       3 print(min(nums))
#
# TypeError: 'int' object is not callable
